# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from datasets import load_dataset
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer, SimpleImputer
from sklearn.kernel_approximation import Nystroem
from sklearn.linear_model import BayesianRidge, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import make_pipeline

# %%
# Load the dataset
dataset_cyclists = load_dataset('csv', data_files='dataset/cyclists.csv')
dataset_races = load_dataset('csv', data_files='dataset/races.csv')

# Convert to pandas DataFrames
df_cyclists = dataset_cyclists['train'].to_pandas()
df_races = dataset_races['train'].to_pandas()

# %% [markdown]
# ## Cyclist

# %%
df_cyclists.head()
# Out:
#                    _url                  name  birth_year  weight  height  \
# 0           bruno-surra          Bruno  Surra      1964.0     NaN     NaN
# 1            gerard-rue           Gérard  Rué      1965.0    74.0   182.0
# 2              jan-maas             Jan  Maas      1996.0    69.0   189.0
# 3  nathan-van-hooydonck  Nathan Van Hooydonck      1995.0    78.0   192.0
# 4      jose-felix-parra     José Félix  Parra      1997.0    55.0   171.0
#
#    nationality
# 0        Italy
# 1       France
# 2  Netherlands
# 3      Belgium
# 4        Spain

# %%
df_cyclists.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6134 entries, 0 to 6133
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _url         6134 non-null   object
#  1   name         6134 non-null   object
#  2   birth_year   6121 non-null   float64
#  3   weight       3078 non-null   float64
#  4   height       3143 non-null   float64
#  5   nationality  6133 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 287.7+ KB

# %%
df_cyclists.shape
# Out:
# (6134, 6)

# %%
# check if there are strange values --> OK
df_cyclists[df_cyclists["birth_year"]=="?"]
df_cyclists[df_cyclists["height"]=="?"]
df_cyclists[df_cyclists["weight"]=="?"]
df_cyclists[df_cyclists["name"]=="?"]
df_cyclists[df_cyclists["nationality"]=="?"]
df_cyclists[df_cyclists["_url"]=="?"]
# Out:
# Empty DataFrame
# Columns: [_url, name, birth_year, weight, height, nationality]
# Index: []

# %%
df_cyclists["birth_year"].unique()
# Out:
# array([1964., 1965., 1996., 1995., 1997., 1998., 1947., 1988., 1984.,
#          nan, 1982., 1980., 1970., 1981., 1985., 1954., 1994., 1951.,
#        1973., 1950., 1979., 1957., 1986., 1991., 1974., 1944., 1962.,
#        2001., 1978., 1952., 1969., 1968., 1943., 1960., 1972., 1975.,
#        1961., 1949., 1966., 1990., 1989., 1983., 1956., 1992., 1999.,
#        2002., 1993., 1959., 1948., 1971., 1977., 1987., 1976., 1967.,
#        1963., 2000., 1955., 1942., 1940., 2003., 1946., 1945., 1953.,
#        1941., 1958., 1933., 1938., 2004., 1939., 1936., 1934., 1937.])

# %%
df_cyclists["birth_year"].value_counts()
# Out:
# birth_year
# 1964.0    145
# 1962.0    141
# 1970.0    140
# 1974.0    138
# 1975.0    133
#          ...
# 1937.0      4
# 1938.0      2
# 1934.0      2
# 1933.0      1
# 1936.0      1
# Name: count, Length: 71, dtype: int64

# %%
df_cyclists["height"].unique()
# Out:
# array([ nan, 182., 189., 192., 171., 177., 191., 175., 178., 181., 172.,
#        174., 180., 164., 170., 184., 185., 186., 190., 179., 193., 167.,
#        173., 176., 183., 166., 187., 188., 195., 169., 198., 194., 168.,
#        199., 204., 154., 165., 159., 160., 196., 162., 161., 163., 155.,
#        158., 197., 202., 157., 200.])

# %%
df_cyclists["height"].value_counts()
# Out:
# height
# 180.0    277
# 178.0    226
# 183.0    193
# 181.0    181
# 175.0    169
# 182.0    165
# 185.0    161
# 176.0    154
# 184.0    152
# 179.0    137
# 177.0    133
# 174.0    129
# 173.0    120
# 186.0    107
# 190.0     97
# 170.0     90
# 187.0     85
# 172.0     80
# 188.0     77
# 171.0     67
# 189.0     48
# 169.0     46
# 191.0     37
# 192.0     34
# 168.0     24
# 167.0     23
# 193.0     22
# 164.0     20
# 194.0     17
# 195.0     13
# 165.0     13
# 196.0      7
# 197.0      6
# 166.0      6
# 160.0      4
# 198.0      4
# 159.0      3
# 162.0      3
# 199.0      2
# 161.0      2
# 163.0      2
# 154.0      1
# 204.0      1
# 155.0      1
# 158.0      1
# 202.0      1
# 157.0      1
# 200.0      1
# Name: count, dtype: int64

# %%
df_cyclists["name"].unique()
# Out:
# array(['Bruno  Surra', 'Gérard  Rué', 'Jan  Maas', ..., 'Paolo  Alberati',
#        'Jackson  Rodríguez', 'Ward  Vanhoof'], dtype=object)

# %%
df_cyclists["name"].value_counts() # duplicates ?
# Out:
# name
# Jesús  López           2
# Roman  Kreuziger       2
# Alberto  Fernández     2
# Antonio  Cabello       2
# Andrea  Peron          2
#                       ..
# Raúl  Rota             1
# Marco Van Der Hulst    1
# Sandy  Casar           1
# Melchor  Mauri         1
# Ward  Vanhoof          1
# Name: count, Length: 6127, dtype: int64

# %%
df_cyclists["nationality"].unique()
# Out:
# array(['Italy', 'France', 'Netherlands', 'Belgium', 'Spain',
#        'United States', None, 'Norway', 'Russia', 'Poland', 'Germany',
#        'Australia', 'Switzerland', 'Ireland', 'Denmark', 'Great Britain',
#        'Colombia', 'South Africa', 'Argentina', 'New Zealand',
#        'Lithuania', 'Portugal', 'Austria', 'Yugoslavia', 'Estonia',
#        'Romania', 'Slovenia', 'Canada', 'Latvia', 'Luxembourg', 'Sweden',
#        'Czech Republic', 'Slovakia', 'Morocco', 'Ukraine', 'Ethiopia',
#        'Belarus', 'Venezuela', 'Japan', 'Mexico', 'Croatia', 'Kazakhstan',
#        'Uruguay', 'Israel', 'Namibia', 'Eritrea', 'Costa Rica', 'Taiwan',
#        'Azerbaijan', 'Hungary', 'Moldova', 'Panama', 'Finland',
#        'Bulgaria', 'Serbia', 'Brazil', 'Iran', 'Greece', 'Chile',
#        'Ecuador', 'China', 'Albania', 'Guatemala', 'Uzbekistan',
#        'Algeria', 'Tunisia', 'Monaco', 'Rwanda', 'Dominican Republic',
#        'Liechtenstein', 'Zimbabwe', 'Puerto Rico', 'Hongkong'],
#       dtype=object)

# %%
df_cyclists["nationality"].value_counts()
# Out:
# nationality
# Italy                 1029
# Spain                  872
# Belgium                869
# France                 741
# Netherlands            380
#                       ...
# Dominican Republic       1
# Liechtenstein            1
# Zimbabwe                 1
# Puerto Rico              1
# Hongkong                 1
# Name: count, Length: 72, dtype: int64

# %%
df_cyclists["weight"].unique()
# Out:
# array([ nan, 74. , 69. , 78. , 55. , 67. , 71.5, 73. , 60. , 65. , 71. ,
#        62. , 63. , 59. , 83. , 76. , 70. , 80. , 72. , 79. , 61. , 68. ,
#        64. , 82. , 56. , 77. , 66. , 75. , 58. , 53. , 57. , 91. , 81. ,
#        88. , 85. , 84. , 86. , 67.5, 89. , 52. , 51. , 54. , 58.5, 48. ,
#        90. , 63.5, 74.5, 66.5, 78.1, 77.5, 81.4, 50. , 87. , 62.5, 93. ,
#        73.5, 79.5, 65.1, 92. , 94. ])

# %%
df_cyclists["weight"].value_counts()
# Out:
# weight
# 70.0    272
# 68.0    219
# 65.0    193
# 67.0    177
# 72.0    169
# 69.0    162
# 73.0    146
# 63.0    140
# 66.0    139
# 64.0    137
# 74.0    135
# 62.0    131
# 75.0    128
# 71.0    125
# 60.0     98
# 61.0     90
# 78.0     86
# 77.0     67
# 58.0     64
# 76.0     63
# 80.0     53
# 59.0     49
# 79.0     30
# 82.0     26
# 55.0     25
# 81.0     22
# 57.0     20
# 83.0     20
# 56.0     19
# 85.0     10
# 53.0      7
# 52.0      6
# 84.0      6
# 54.0      4
# 51.0      4
# 90.0      4
# 88.0      3
# 87.0      3
# 50.0      2
# 86.0      2
# 58.5      2
# 63.5      2
# 89.0      2
# 67.5      1
# 92.0      1
# 65.1      1
# 79.5      1
# 73.5      1
# 93.0      1
# 62.5      1
# 78.1      1
# 81.4      1
# 77.5      1
# 66.5      1
# 74.5      1
# 91.0      1
# 48.0      1
# 71.5      1
# 94.0      1
# Name: count, dtype: int64

# %%
df_cyclists["_url"].unique()
# Out:
# array(['bruno-surra', 'gerard-rue', 'jan-maas', ..., 'paolo-alberati',
#        'jackson-rodriguez', 'ward-vanhoof'], dtype=object)

# %%
df_cyclists["_url"].value_counts()
# Out:
# _url
# bruno-surra               1
# rossano-brasi             1
# camilo-andres-suarez      1
# marco-gilli               1
# nelson-rodriguez-serna    1
#                          ..
# claudio-fasolo            1
# raul-rota-rus             1
# marco-van-der-hulst       1
# sandy-casar               1
# ward-vanhoof              1
# Name: count, Length: 6134, dtype: int64

# %%
df_cyclists.describe()
# Out:
#         birth_year       weight       height
# count  6121.000000  3078.000000  3143.000000
# mean   1974.071884    68.658739   179.815145
# std      15.535834     6.348183     6.443447
# min    1933.000000    48.000000   154.000000
# 25%    1962.000000    64.000000   175.000000
# 50%    1974.000000    69.000000   180.000000
# 75%    1987.000000    73.000000   184.000000
# max    2004.000000    94.000000   204.000000

# %%
df_cyclists[df_cyclists["birth_year"]==2004.0] # okay
# Out:
#                      _url             name  birth_year  weight  height  \
# 806        joshua-tarling  Joshua  Tarling      2004.0    78.0   194.0
# 1795         jan-christen    Jan  Christen      2004.0    60.0   183.0
# 3043  rafael-elvas-barbas   Rafael  Barbas      2004.0    67.0   189.0
# 3968          tiago-nunes     Tiago  Nunes      2004.0     NaN     NaN
# 5684         paul-magnier    Paul  Magnier      2004.0    75.0   187.0
#
#         nationality
# 806   Great Britain
# 1795    Switzerland
# 3043       Portugal
# 3968       Portugal
# 5684         France

# %%
# check duplicates
dup_df_cyclist = df_cyclists[df_cyclists.duplicated(keep=False)]

# %%
dup_df_cyclist # no dup rows for all the column
# Out:
# Empty DataFrame
# Columns: [_url, name, birth_year, weight, height, nationality]
# Index: []

# %%
# check for the name
dup_df_cyclist = df_cyclists[df_cyclists.duplicated(subset=["name"], keep=False)]

# %%
dup_df_cyclist # they are different person, no duplicates
# Out:
#                             _url                name  birth_year  weight  \
# 347               andrea-peron-1       Andrea  Peron      1971.0    70.0
# 1745          roman-kreuziger-sr    Roman  Kreuziger      1965.0     NaN
# 2235           alessandro-pozzi2   Alessandro  Pozzi      1969.0     NaN
# 2601             roman-kreuziger    Roman  Kreuziger      1986.0    65.0
# 2682                andrea-peron       Andrea  Peron      1988.0    70.0
# 2862       antonio-cabello-baena    Antonio  Cabello      1990.0    67.0
# 2939               jesus-lopez23        Jesús  López      1955.0     NaN
# 2953     alberto-fernandez-sainz  Alberto  Fernández      1981.0     NaN
# 3238             antonio-cabello    Antonio  Cabello      1956.0     NaN
# 4917  sergio-dominguez-rodriguez   Sergio  Domínguez      1979.0     NaN
# 4919      sergio-dominguez-munoz   Sergio  Domínguez      1986.0     NaN
# 5040          jesus-lopez-carril        Jesús  López      1949.0     NaN
# 5720    alberto-fernandez-blanco  Alberto  Fernández      1955.0     NaN
# 5722            alessandro-pozzi   Alessandro  Pozzi      1954.0     NaN
#
#       height     nationality
# 347    183.0           Italy
# 1745     NaN  Czech Republic
# 2235     NaN           Italy
# 2601   183.0  Czech Republic
# 2682   178.0           Italy
# 2862   179.0           Spain
# 2939     NaN           Spain
# 2953     NaN           Spain
# 3238     NaN           Spain
# 4917     NaN           Spain
# 4919     NaN           Spain
# 5040     NaN           Spain
# 5720     NaN           Spain
# 5722     NaN           Italy

# %%
df_cyclists[df_cyclists.duplicated(subset=["_url"], keep=False)] # no dupilcates, rest has no sense
# Out:
# Empty DataFrame
# Columns: [_url, name, birth_year, weight, height, nationality]
# Index: []

# %% [markdown]
# ## Missing values

# %%
# check missing values
df_cyclists.isnull().sum()
# Out:
# _url              0
# name              0
# birth_year       13
# weight         3056
# height         2991
# nationality       1
# dtype: int64

# %%
# Check information about scott-davies in the other dataset to put some value in
df_cyclists[df_cyclists["_url"] == "scott-davies"]
# Out:
#            _url           name  birth_year  weight  height nationality
# 9  scott-davies  Scott  Davies         NaN     NaN     NaN        None

# %%
# unable to find meaningful information about the cyclist, so since it's 1 just delete him
scott_davies_df = df_races[df_races["cyclist"] == "scott-davies"]
scott_davies_df
# Out:
#                                  _url                         name  points  \
# 2063      giro-d-italia/2019/stage-14                Giro d'Italia    80.0
# 6495     vuelta-a-espana/2020/stage-7  La Vuelta ciclista a España    80.0
# 12865    amstel-gold-race/2018/result             Amstel Gold Race   225.0
# 12972   vuelta-a-espana/2020/stage-11  La Vuelta ciclista a España    80.0
# 13349         paris-nice/2019/stage-3                 Paris - Nice    50.0
# 23038     giro-d-italia/2019/stage-16                Giro d'Italia    80.0
# 60389    vuelta-a-espana/2020/stage-4  La Vuelta ciclista a España    80.0
# 68791      giro-d-italia/2019/stage-9                Giro d'Italia    80.0
# 75497     giro-d-italia/2019/stage-18                Giro d'Italia    80.0
# 132853        paris-nice/2019/stage-1                 Paris - Nice    50.0
# 155617     giro-d-italia/2019/stage-5                Giro d'Italia    80.0
# 171862     giro-d-italia/2019/stage-3                Giro d'Italia    80.0
# 174217    giro-d-italia/2019/stage-13                Giro d'Italia    80.0
# 180506     giro-d-italia/2019/stage-6                Giro d'Italia    80.0
# 189206  vuelta-a-espana/2020/stage-18  La Vuelta ciclista a España    80.0
# 197959     giro-d-italia/2019/stage-8                Giro d'Italia    80.0
# 217090    giro-d-italia/2019/stage-10                Giro d'Italia    80.0
# 217425   vuelta-a-espana/2020/stage-5  La Vuelta ciclista a España    80.0
# 273299        paris-nice/2019/stage-5                 Paris - Nice    50.0
# 277402    giro-d-italia/2019/stage-12                Giro d'Italia    80.0
# 283649    tour-de-suisse/2018/stage-5               Tour de Suisse    50.0
# 292037     giro-d-italia/2019/stage-2                Giro d'Italia    80.0
# 324670   vuelta-a-espana/2020/stage-9  La Vuelta ciclista a España    80.0
# 329037   vuelta-a-espana/2020/stage-2  La Vuelta ciclista a España    80.0
# 332435  vuelta-a-espana/2020/stage-12  La Vuelta ciclista a España    80.0
# 353917   vuelta-a-espana/2020/stage-3  La Vuelta ciclista a España    80.0
# 357302  vuelta-a-espana/2020/stage-16  La Vuelta ciclista a España    80.0
# 392873    giro-d-italia/2019/stage-19                Giro d'Italia    80.0
# 404577  vuelta-a-espana/2020/stage-14  La Vuelta ciclista a España    80.0
# 405815   vuelta-a-espana/2020/stage-6  La Vuelta ciclista a España    80.0
# 408819     giro-d-italia/2019/stage-1                Giro d'Italia    80.0
# 412521        paris-nice/2019/stage-6                 Paris - Nice    50.0
# 416419        paris-nice/2019/stage-7                 Paris - Nice    50.0
# 421587  vuelta-a-espana/2020/stage-13  La Vuelta ciclista a España    80.0
# 422259    giro-d-italia/2019/stage-20                Giro d'Italia    80.0
# 422762    tour-de-suisse/2018/stage-3               Tour de Suisse    50.0
# 428445    tour-de-suisse/2018/stage-2               Tour de Suisse    50.0
# 428837     giro-d-italia/2019/stage-4                Giro d'Italia    80.0
# 456303        paris-nice/2019/stage-8                 Paris - Nice    50.0
# 462363        paris-nice/2019/stage-4                 Paris - Nice    50.0
# 467602        paris-nice/2019/stage-2                 Paris - Nice    50.0
# 469315  vuelta-a-espana/2020/stage-15  La Vuelta ciclista a España    80.0
# 472449  vuelta-a-espana/2020/stage-10  La Vuelta ciclista a España    80.0
# 499538  vuelta-a-espana/2020/stage-17  La Vuelta ciclista a España    80.0
# 501068    giro-d-italia/2019/stage-17                Giro d'Italia    80.0
# 503971     giro-d-italia/2019/stage-7                Giro d'Italia    80.0
# 511387    tour-de-suisse/2018/stage-4               Tour de Suisse    50.0
# 535955    giro-d-italia/2019/stage-15                Giro d'Italia    80.0
# 538467    giro-d-italia/2019/stage-11                Giro d'Italia    80.0
# 547471   vuelta-a-espana/2020/stage-8  La Vuelta ciclista a España    80.0
# 560444   vuelta-a-espana/2020/stage-1  La Vuelta ciclista a España    80.0
# 580851    giro-d-italia/2019/stage-21                Giro d'Italia    80.0
#
#         uci_points    length  climb_total  profile  startlist_quality  \
# 2063         100.0  131000.0       4187.0      4.0                896
# 6495         100.0  159700.0       2657.0      2.0                692
# 12865        500.0  263000.0       3496.0      2.0               1139
# 12972        100.0  170000.0       5098.0      5.0                692
# 13349         60.0  200000.0        896.0      1.0               1099
# 23038        100.0  194000.0       5207.0      4.0                896
# 60389        100.0  191700.0       1160.0      1.0                692
# 68791        100.0   34800.0        723.0      3.0                896
# 75497        100.0  222000.0       1478.0      2.0                896
# 132853        60.0  138500.0       1107.0      1.0               1099
# 155617       100.0  140000.0       2056.0      2.0                896
# 171862       100.0  220000.0       1790.0      2.0                896
# 174217       100.0  196000.0       5187.0      5.0                896
# 180506       100.0  238000.0       2881.0      2.0                896
# 189206       100.0  139600.0       1492.0      2.0                692
# 197959       100.0  239000.0       1998.0      2.0                896
# 217090       100.0  145000.0        160.0      1.0                896
# 217425       100.0  184400.0       3407.0      3.0                692
# 273299        60.0   25500.0        157.0      1.0               1099
# 277402       100.0  158000.0       1918.0      4.0                896
# 283649        60.0  155000.0       2668.0      5.0                956
# 292037       100.0  205000.0       2242.0      2.0                896
# 324670       100.0  157700.0       1163.0      1.0                692
# 329037       100.0  151600.0       2435.0      4.0                692
# 332435       100.0  109400.0       3125.0      5.0                692
# 353917       100.0  166100.0       2779.0      5.0                692
# 357302       100.0  162000.0       2762.0      2.0                692
# 392873       100.0  151000.0       3169.0      5.0                896
# 404577       100.0  204700.0       3057.0      3.0                692
# 405815       100.0  146400.0       3020.0      5.0                692
# 408819       100.0    8000.0        291.0      3.0                896
# 412521        60.0  176500.0       2029.0      4.0               1099
# 416419        60.0  181500.0       4332.0      5.0               1099
# 421587       100.0   33700.0        536.0      3.0                692
# 422259       100.0  194000.0       5754.0      5.0                896
# 422762        60.0  182000.0       2260.0      2.0                956
# 428445        60.0  155000.0       1817.0      2.0                956
# 428837       100.0  235000.0       2995.0      3.0                896
# 456303        60.0  110000.0       2165.0      4.0               1099
# 462363        60.0  212000.0       2969.0      2.0               1099
# 467602        60.0  163500.0        753.0      1.0               1099
# 469315       100.0  230800.0       4448.0      2.0                692
# 472449       100.0  185000.0       2302.0      3.0                692
# 499538       100.0  178200.0       4365.0      5.0                692
# 501068       100.0  181000.0       3482.0      5.0                896
# 503971       100.0  185000.0       2626.0      2.0                896
# 511387        60.0  189000.0       2467.0      5.0                956
# 535955       100.0  232000.0       3122.0      3.0                896
# 538467       100.0  221000.0        476.0      1.0                896
# 547471       100.0  164000.0       3021.0      5.0                692
# 560444       100.0  173000.0       2975.0      2.0                692
# 580851       100.0   17000.0        297.0      2.0                896
#
#         average_temperature                 date  position       cyclist  \
# 2063                    NaN  2019-05-25 04:31:35        99  scott-davies
# 6495                    NaN  2020-10-27 04:05:14       124  scott-davies
# 12865                   NaN  2018-04-15 06:39:57        96  scott-davies
# 12972                   NaN  2020-10-31 05:26:30       100  scott-davies
# 13349                   NaN  2019-03-12 05:16:25        50  scott-davies
# 23038                   NaN  2019-05-28 05:58:48        71  scott-davies
# 60389                   NaN  2020-10-23 03:54:11       134  scott-davies
# 68791                   NaN  2019-05-19 00:54:29        18  scott-davies
# 75497                   NaN  2019-05-30 05:04:24       138  scott-davies
# 132853                  NaN  2019-03-10 03:20:17       131  scott-davies
# 155617                  NaN  2019-05-15 03:15:44       143  scott-davies
# 171862                  NaN  2019-05-13 05:24:05        83  scott-davies
# 174217                  NaN  2019-05-24 06:08:31        96  scott-davies
# 180506                  NaN  2019-05-16 06:08:09       148  scott-davies
# 189206                  NaN  2020-11-08 03:28:49        87  scott-davies
# 197959                  NaN  2019-05-18 05:55:25       148  scott-davies
# 217090                  NaN  2019-05-21 03:39:43       147  scott-davies
# 217425                  NaN  2020-10-24 04:32:14       120  scott-davies
# 273299                  NaN  2019-03-14 00:31:39        26  scott-davies
# 277402                  NaN  2019-05-23 04:01:51       111  scott-davies
# 283649                  NaN  2018-06-13 03:56:07        72  scott-davies
# 292037                  NaN  2019-05-12 04:56:53       157  scott-davies
# 324670                  NaN  2020-10-29 03:41:45       127  scott-davies
# 329037                  NaN  2020-10-21 04:02:30        63  scott-davies
# 332435                  NaN  2020-11-01 03:34:29        74  scott-davies
# 353917                  NaN  2020-10-22 04:39:03       107  scott-davies
# 357302                  NaN  2020-11-06 04:17:48        79  scott-davies
# 392873                  NaN  2019-05-31 04:20:01        94  scott-davies
# 404577                  NaN  2020-11-04 04:48:32       133  scott-davies
# 405815                  NaN  2020-10-25 03:58:11       111  scott-davies
# 408819                  NaN  2019-05-11 00:14:08        42  scott-davies
# 412521                  NaN  2019-03-15 04:18:16        60  scott-davies
# 416419                  NaN  2019-03-16 05:08:18        47  scott-davies
# 421587                  NaN  2020-11-03 00:49:21        31  scott-davies
# 422259                  NaN  2019-06-01 06:26:48       106  scott-davies
# 422762                  NaN  2018-06-11 04:42:02        87  scott-davies
# 428445                  NaN  2018-06-10 03:50:09        59  scott-davies
# 428837                  NaN  2019-05-14 06:11:09       156  scott-davies
# 456303                  NaN  2019-03-17 02:57:50       100  scott-davies
# 462363                  NaN  2019-03-13 05:10:44        64  scott-davies
# 467602                  NaN  2019-03-11 03:15:23        54  scott-davies
# 469315                  NaN  2020-11-05 06:32:52       128  scott-davies
# 472449                  NaN  2020-10-30 04:14:43        53  scott-davies
# 499538                  NaN  2020-11-07 05:28:03        92  scott-davies
# 501068                  NaN  2019-05-29 05:06:02        96  scott-davies
# 503971                  NaN  2019-05-17 04:24:33       135  scott-davies
# 511387                  NaN  2018-06-12 04:36:04        58  scott-davies
# 535955                  NaN  2019-05-26 06:20:00        83  scott-davies
# 538467                  NaN  2019-05-22 05:20:44       156  scott-davies
# 547471                  NaN  2020-10-28 04:26:21        90  scott-davies
# 560444                  NaN  2020-10-20 04:37:54       109  scott-davies
# 580851                  NaN  2019-06-02 00:23:25        39  scott-davies
#
#         cyclist_age  is_tarmac  is_cobbled  is_gravel  \
# 2063            NaN       True       False      False
# 6495            NaN       True       False      False
# 12865           NaN      False       False      False
# 12972           NaN       True       False      False
# 13349           NaN       True       False      False
# 23038           NaN       True       False      False
# 60389           NaN       True       False      False
# 68791           NaN       True       False      False
# 75497           NaN       True       False      False
# 132853          NaN       True       False      False
# 155617          NaN       True       False      False
# 171862          NaN       True       False      False
# 174217          NaN       True       False      False
# 180506          NaN       True       False      False
# 189206          NaN       True       False      False
# 197959          NaN       True       False      False
# 217090          NaN       True       False      False
# 217425          NaN       True       False      False
# 273299          NaN       True       False      False
# 277402          NaN       True       False      False
# 283649          NaN       True       False      False
# 292037          NaN       True       False      False
# 324670          NaN       True       False      False
# 329037          NaN       True       False      False
# 332435          NaN       True       False      False
# 353917          NaN       True       False      False
# 357302          NaN       True       False      False
# 392873          NaN       True       False      False
# 404577          NaN       True       False      False
# 405815          NaN       True       False      False
# 408819          NaN       True       False      False
# 412521          NaN       True       False      False
# 416419          NaN       True       False      False
# 421587          NaN       True       False      False
# 422259          NaN       True       False      False
# 422762          NaN       True       False      False
# 428445          NaN       True       False      False
# 428837          NaN       True       False      False
# 456303          NaN       True       False      False
# 462363          NaN       True       False      False
# 467602          NaN       True       False      False
# 469315          NaN       True       False      False
# 472449          NaN       True       False      False
# 499538          NaN       True       False      False
# 501068          NaN       True       False      False
# 503971          NaN       True       False      False
# 511387          NaN       True       False      False
# 535955          NaN       True       False      False
# 538467          NaN       True       False      False
# 547471          NaN       True       False      False
# 560444          NaN       True       False      False
# 580851          NaN       True       False      False
#
#                    cyclist_team   delta
# 2063    team-giant-shimano-2014  1752.0
# 6495      carrera-inoxpran-1985  1018.0
# 12865             liquigas-2007   290.0
# 12972     carrera-inoxpran-1985  1937.0
# 13349   team-giant-shimano-2014     0.0
# 23038   team-giant-shimano-2014  1344.0
# 60389     carrera-inoxpran-1985    42.0
# 68791   team-giant-shimano-2014   157.0
# 75497   team-giant-shimano-2014   500.0
# 132853  team-giant-shimano-2014   162.0
# 155617  team-giant-shimano-2014     0.0
# 171862  team-giant-shimano-2014    46.0
# 174217  team-giant-shimano-2014  2031.0
# 180506  team-giant-shimano-2014  1388.0
# 189206    carrera-inoxpran-1985    36.0
# 197959  team-giant-shimano-2014   713.0
# 217090  team-giant-shimano-2014   216.0
# 217425    carrera-inoxpran-1985   769.0
# 273299  team-giant-shimano-2014    73.0
# 277402  team-giant-shimano-2014  1202.0
# 283649            liquigas-2007  1116.0
# 292037  team-giant-shimano-2014   730.0
# 324670    carrera-inoxpran-1985   110.0
# 329037    carrera-inoxpran-1985   926.0
# 332435    carrera-inoxpran-1985  1549.0
# 353917    carrera-inoxpran-1985   674.0
# 357302    carrera-inoxpran-1985   793.0
# 392873  team-giant-shimano-2014  1110.0
# 404577    carrera-inoxpran-1985   687.0
# 405815    carrera-inoxpran-1985  1031.0
# 408819  team-giant-shimano-2014    74.0
# 412521  team-giant-shimano-2014   341.0
# 416419  team-giant-shimano-2014   749.0
# 421587    carrera-inoxpran-1985   162.0
# 422259  team-giant-shimano-2014  2446.0
# 422762            liquigas-2007   131.0
# 428445            liquigas-2007     0.0
# 428837  team-giant-shimano-2014   772.0
# 456303  team-giant-shimano-2014  1000.0
# 462363  team-giant-shimano-2014   415.0
# 467602  team-giant-shimano-2014    79.0
# 469315    carrera-inoxpran-1985   835.0
# 472449    carrera-inoxpran-1985    32.0
# 499538    carrera-inoxpran-1985  2011.0
# 501068  team-giant-shimano-2014  1468.0
# 503971  team-giant-shimano-2014  1086.0
# 511387            liquigas-2007     8.0
# 535955  team-giant-shimano-2014  1905.0
# 538467  team-giant-shimano-2014   198.0
# 547471    carrera-inoxpran-1985  1153.0
# 560444    carrera-inoxpran-1985   920.0
# 580851  team-giant-shimano-2014    78.0

# %%
# delete the row
df_cyclists = df_cyclists[df_cyclists["_url"] != "scott-davies"]

# %% [markdown]
# plot distribution of attributes before and then after manage missing values to see if change drastically

# %%
# Kernel Density Estimation
seaborn.kdeplot(df_cyclists["birth_year"], fill=True, label="birth_year")
plt.show()

# %%
seaborn.kdeplot(df_cyclists["weight"], fill=True, label="weight")
plt.show()

# %%
seaborn.kdeplot(df_cyclists["height"], fill=True, label="height")
plt.show()

# %% [markdown]
# ## Compute optimal number of bins

# %%
# Sturges rule for approximately Normal distributions
def sturges_bin_count(df_cyclists):
    """Calculate optimal number of bins based on Sturges' rule"""
    return int(np.ceil(np.log2(len(df_cyclists)) + 1))

bins = sturges_bin_count(df_cyclists["weight"])
print(f"Recommended number of bins: {bins}")

# Freedman-Diaconis Rule is better for data with outliers and skewed distributions
def freedman_diaconis_bin_count(data):
    """Calculate optimal number of bins based on Freedman-Diaconis rule"""
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    bin_width = 2 * iqr * len(data) ** (-1/3)
    return int(np.ceil((data.max() - data.min()) / bin_width))

bins = freedman_diaconis_bin_count(df_cyclists["weight"])
print(f"Recommended number of bins: {bins}")
# Out:
# Recommended number of bins: 14
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 16
#      13     bin_width = 2 * iqr * len(data) ** (-1/3)
#      14     return int(np.ceil((data.max() - data.min()) / bin_width))
# ---> 16 bins = freedman_diaconis_bin_count(df_cyclists["weight"])
#      17 print(f"Recommended number of bins: {bins}")
#
# Cell In[34], line 14, in freedman_diaconis_bin_count(data)
#      12 iqr = np.percentile(data, 75) - np.percentile(data, 25)
#      13 bin_width = 2 * iqr * len(data) ** (-1/3)
# ---> 14 return int(np.ceil((data.max() - data.min()) / bin_width))
#
# ValueError: cannot convert float NaN to integer

# %%
# birht year
seaborn.displot(df_cyclists,
                x="birth_year",
                kind="hist",
                row_order="desc",
                bins=15)

# %%
# weight
seaborn.displot(df_cyclists,
                x="weight",
                kind="hist",
                row_order="desc",
                bins=14)

# %%
# height
seaborn.displot(df_cyclists,
                x="height",
                kind="hist",
                row_order="desc",
                bins=14)

# %% [markdown]
# ## SimpleImputer for birth year
# It seems good wrt the distribution. Since they are only 13, we keep that

# %%
# try simple imputer
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
imputer.fit((df_cyclists[["birth_year"]]))
df_cyclists["birth_year"] = imputer.transform(df_cyclists[["birth_year"]]).squeeze()

# %%
df_cyclists.isnull().sum() # zero missing values for birth year
# Out:
# _url              0
# name              0
# birth_year        0
# weight         3055
# height         2990
# nationality       0
# dtype: int64

# %% [markdown]
# ### Review distribution of birth year --> OKAY seems reasonably the same

# %%
# review distribution of birth year --> OKAY seems reasonably the same
seaborn.displot(df_cyclists,
                x="birth_year",
                kind="hist",
                row_order="desc",
                bins=15)

# %% [markdown]
# # KNN imputer test for weight

# %%
# try simple imputer
from sklearn.impute import KNNImputer

# create test dataset for testing weight and height replacement with KNN
test_df_cyclists = df_cyclists
imputer = KNNImputer(n_neighbors=2,weights="distance")
imputer.fit((test_df_cyclists[["weight"]]))
test_df_cyclists["weight"] = imputer.transform(test_df_cyclists[["weight"]]).squeeze()

# %%
# review distribution of weight --> NOT GOOD 
seaborn.displot(test_df_cyclists,
                x="weight",
                kind="hist",
                row_order="desc",
                bins=15)

# %% [markdown]
# ## Iterative Imputer for weight

# %% [markdown]
# Flexibility of IterativeImputer
# There are many well-established imputation packages in the R data science ecosystem: Amelia, mi, mice, missForest, etc. missForest is popular, and turns out to be a particular instance of different sequential imputation algorithms that can all be implemented with IterativeImputer by passing in different regressors to be used for predicting missing feature values.
#
# Multiple vs. Single Imputation
# In the statistics community, it is common practice to perform multiple imputations, generating, for example, m separate imputations for a single feature matrix. Each of these m imputations is then put through the subsequent analysis pipeline (e.g. feature engineering, clustering, regression, classification). The m final analysis results (e.g. held-out validation errors) allow the data scientist to obtain understanding of how analytic results may differ as a consequence of the inherent uncertainty caused by the missing values. The above practice is called multiple imputation.
#
# Our implementation of IterativeImputer was inspired by the R MICE package (Multivariate Imputation by Chained Equations) [1], but differs from it by returning a single imputation instead of multiple imputations. However, IterativeImputer can also be used for multiple imputations by applying it repeatedly to the same dataset with different random seeds when sample_posterior=True

# %% [markdown]
# Multiple imputation --> different datasets generated
#
# The parameter sample_posterior in sklearn's IterativeImputer is directly related to multiple imputation. Let's break it down:
#
# Iterative Imputer: This method models each feature with missing values as a function of other features, and iteratively imputes the missing values.
#
# Posterior Distribution: The term "posterior" in this context refers to the posterior distribution of the missing data. When sample_posterior=True, it draws imputed values from the posterior distribution of the predicted values, which adds randomness (or variability) to the imputed values. This means that for the same missing value, multiple imputations will yield different (randomly sampled) values, thus generating multiple plausible datasets.
#
# When sample_posterior=True: The imputed values are not just the most likely (expected) value but are randomly sampled from the predicted distribution. This randomness is important in multiple imputation because it reflects the uncertainty about the imputed values.

# %%
df_cyclists_impute = df_cyclists[['height', 'weight']].copy()

print("Shape of original DataFrame:", df_cyclists.shape)
print("Shape of imputed DataFrame:", df_cyclists_impute.shape)
# Step 2: Normalize/Scale the relevant features (birth_year, height)
#scaler = StandardScaler()
#df_cyclists_impute[['birth_year', 'height']] = scaler.fit_transform(df_cyclists_impute[['birth_year', 'height']])

iterative_imputer = IterativeImputer(
    estimator=BayesianRidge(),
    random_state=0,
    max_iter=100,
    sample_posterior=True
)

# Fit the imputer and transform the DataFrame
imputed_values = iterative_imputer.fit_transform(df_cyclists_impute)
# Create a new DataFrame with the imputed values
df_imputed = pd.DataFrame(imputed_values, columns=df_cyclists_impute.columns)

# Display the original and imputed DataFrames
#print("Original DataFrame:\n", df_cyclists)
print("\nImputed DataFrame:\n", df_imputed)
# Out:
# Shape of original DataFrame: (6133, 6)
# Shape of imputed DataFrame: (6133, 2)
#
# Imputed DataFrame:
#            height     weight
# 0     187.597309  69.812385
# 1     182.000000  74.000000
# 2     189.000000  69.000000
# 3     192.000000  78.000000
# 4     171.000000  55.000000
# ...          ...        ...
# 6128  187.722968  72.047719
# 6129  188.000000  75.000000
# 6130  166.849741  58.058737
# 6131  170.000000  58.000000
# 6132  186.000000  75.000000
#
# [6133 rows x 2 columns]

# %%
# check len of new imputed data
len(df_imputed)
# Out:
# 6133

# %%
# Visualize the distributions of imputed height and weight
df_long = pd.melt(df_imputed, value_vars=['height', 'weight'], var_name='attribute', value_name='value')

seaborn.displot(df_long, x='value', hue='attribute', kind='kde', fill=True, common_norm=False)
plt.title('Distribution of Imputed Height and Weight Values')
plt.show()

# %%
# review distribution of weight --> GOOD 
seaborn.displot(df_imputed,
                x="weight",
                kind="hist",
                row_order="desc",
                bins=14)

# %%
# review distribution of height --> GOOD
seaborn.displot(df_imputed,
                x="height",
                kind="hist",
                row_order="desc",
                bins=14)

# %% [markdown]
# ### Distributions are pretty good --> TODO: adjust estimators/parameters and try different models for iterative imputer (regression / knn + hyperparameters tuning)

# %% [markdown]
# 1. Try standardizing data

# %%
df_cyclists_impute_scaling = df_cyclists[['height', 'weight']].copy()

print("Shape of original DataFrame:", df_cyclists.shape)
print("Shape of imputed DataFrame:", df_cyclists_impute_scaling.shape)

# Normalize/Scale 
scaler = StandardScaler()
df_cyclists_impute_scaling[['weight', 'height']] = scaler.fit_transform(df_cyclists_impute_scaling[['weight', 'height']])

iterative_imputer = IterativeImputer(
    estimator=BayesianRidge(),
    random_state=0,
    max_iter=100,
    sample_posterior=True
)

# Fit the imputer and transform the DataFrame
imputed_values = iterative_imputer.fit_transform(df_cyclists_impute_scaling)
# Create a new DataFrame with the imputed values
df_imputed_scaling = pd.DataFrame(imputed_values, columns=df_cyclists_impute_scaling.columns)

# revert scaling
df_imputed_scaling = pd.DataFrame(
    scaler.inverse_transform(df_imputed_scaling),  
    columns=df_imputed_scaling.columns
)

# Display the original and imputed DataFrames
#print("Original DataFrame:\n", df_cyclists_impute_scaling)
print("\nImputed DataFrame:\n", df_imputed_scaling)
# Out:
# Shape of original DataFrame: (6133, 6)
# Shape of imputed DataFrame: (6133, 2)
#
# Imputed DataFrame:
#           height      weight
# 0     75.957074  181.234462
# 1     70.811285  185.236578
# 2     77.707768  180.161528
# 3     80.663404  189.296618
# 4     59.973954  165.951387
# ...         ...         ...
# 6128  76.166234  183.313649
# 6129  76.722556  186.251588
# 6130  56.882074  169.916741
# 6131  58.988742  168.996417
# 6132  74.752133  186.251588
#
# [6133 rows x 2 columns]

# %%
# review distribution of weight --> GOOD 
seaborn.displot(df_imputed_scaling,
                x="weight",
                kind="hist",
                row_order="desc",
                bins=14)

# %%
# review distribution of height --> GOOD 
seaborn.displot(df_imputed_scaling,
                x="height",
                kind="hist",
                row_order="desc",
                bins=14)

# %% [markdown]
# 2. Try another model --> random forest (non linear)
# 3. Tune tolerance and max iteration parameters of the imputator

# %%
df_cyclists_impute_scaling_rf = df_cyclists[['height', 'weight']].copy()

print("Shape of original DataFrame:", df_cyclists.shape)
print("Shape of imputed DataFrame:", df_cyclists_impute_scaling_rf.shape)

# Normalize/Scale 
scaler = StandardScaler()
df_cyclists_impute_scaling_rf[['weight', 'height']] = scaler.fit_transform(df_cyclists_impute_scaling_rf[['weight', 'height']])

iterative_imputer = IterativeImputer(
    estimator=RandomForestRegressor(),
    random_state=0,
    max_iter=400,
    sample_posterior=False
)

# Fit the imputer and transform the DataFrame
imputed_values = iterative_imputer.fit_transform(df_cyclists_impute_scaling_rf)
# Create a new DataFrame with the imputed values
df_imputed_scaling_rf = pd.DataFrame(imputed_values, columns=df_cyclists_impute_scaling_rf.columns)

# revert scaling
df_imputed_scaling_rf = pd.DataFrame(
    scaler.inverse_transform(df_imputed_scaling_rf),  
    columns=df_imputed_scaling_rf.columns
)

# Display the original and imputed DataFrames
#print("Original DataFrame:\n", df_cyclists_impute_scaling)
print("\nImputed DataFrame:\n", df_imputed_scaling_rf)
# Out:
# Shape of original DataFrame: (6133, 6)
# Shape of imputed DataFrame: (6133, 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 18
#      10 iterative_imputer = IterativeImputer(
#      11     estimator=RandomForestRegressor(),
#      12     random_state=0,
#      13     max_iter=400,
#      14     sample_posterior=False
#      15 )
#      17 # Fit the imputer and transform the DataFrame
# ---> 18 imputed_values = iterative_imputer.fit_transform(df_cyclists_impute_scaling_rf)
#      19 # Create a new DataFrame with the imputed values
#      20 df_imputed_scaling_rf = pd.DataFrame(imputed_values, columns=df_cyclists_impute_scaling_rf.columns)
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/impute/_iterative.py:765, in IterativeImputer.fit_transform(self, X, y)
#     761 for feat_idx in ordered_idx:
#     762     neighbor_feat_idx = self._get_neighbor_feat_idx(
#     763         n_features, feat_idx, abs_corr_mat
#     764     )
# --> 765     Xt, estimator = self._impute_one_feature(
#     766         Xt,
#     767         mask_missing_values,
#     768         feat_idx,
#     769         neighbor_feat_idx,
#     770         estimator=None,
#     771         fit_mode=True,
#     772     )
#     773     estimator_triplet = _ImputerTriplet(
#     774         feat_idx, neighbor_feat_idx, estimator
#     775     )
#     776     self.imputation_sequence_.append(estimator_triplet)
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/impute/_iterative.py:412, in IterativeImputer._impute_one_feature(self, X_filled, mask_missing_values, feat_idx, neighbor_feat_idx, estimator, fit_mode)
#     402     X_train = _safe_indexing(
#     403         _safe_indexing(X_filled, neighbor_feat_idx, axis=1),
#     404         ~missing_row_mask,
#     405         axis=0,
#     406     )
#     407     y_train = _safe_indexing(
#     408         _safe_indexing(X_filled, feat_idx, axis=1),
#     409         ~missing_row_mask,
#     410         axis=0,
#     411     )
# --> 412     estimator.fit(X_train, y_train)
#     414 # if no missing values, don't predict
#     415 if np.sum(missing_row_mask) == 0:
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:456, in BaseForest.fit(self, X, y, sample_weight)
#     445 trees = [
#     446     self._make_estimator(append=False, random_state=random_state)
#     447     for i in range(n_more_estimators)
#     448 ]
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
# --> 456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#     459     prefer="threads",
#     460 )(
#     461     delayed(_parallel_build_trees)(
#     462         t,
#     463         self.bootstrap,
#     464         X,
#     465         y,
#     466         sample_weight,
#     467         i,
#     468         len(trees),
#     469         verbose=self.verbose,
#     470         class_weight=self.class_weight,
#     471         n_samples_bootstrap=n_samples_bootstrap,
#     472     )
#     473     for i, t in enumerate(trees)
#     474 )
#     476 # Collect newly grown trees
#     477 self.estimators_.extend(trees)
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     189 else:
#     190     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/tree/_classes.py:1320, in DecisionTreeRegressor.fit(self, X, y, sample_weight, check_input)
#    1290 @_fit_context(prefer_skip_nested_validation=True)
#    1291 def fit(self, X, y, sample_weight=None, check_input=True):
#    1292     """Build a decision tree regressor from the training set (X, y).
#    1293
#    1294     Parameters
#    (...)
#    1317         Fitted estimator.
#    1318     """
# -> 1320     super()._fit(
#    1321         X,
#    1322         y,
#    1323         sample_weight=sample_weight,
#    1324         check_input=check_input,
#    1325     )
#    1326     return self
#
# File /opt/anaconda3/envs/tf_env4/lib/python3.8/site-packages/sklearn/tree/_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
